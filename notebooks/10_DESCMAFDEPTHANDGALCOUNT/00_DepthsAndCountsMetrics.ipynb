# %% [markdown]
# # Galaxy Count Metrics

# %%
from rubin_sim import maf
from rubin_sim.maf.metrics.exgal_m5 import ExgalM5
from rubin_sim.maf.maf_contrib.depth_limited_num_gal_metric import GalaxyCountsMetric
from rubin_sim.maf.maf_contrib.lss_obs_strategy.galaxy_counts_metric_extended import (
    GalaxyCountsMetricExtended,
)
from rubin_sim.maf.maf_contrib.depth_limited_num_gal_metric import DepthLimitedNumGalMetric

# %% [markdown]
# ## 1 MAF metric ExgalM5
# - https://github.com/lsst/rubin_sim/blob/main/rubin_sim/maf/metrics/exgal_m5.py
# - https://github.com/lsst/rubin_sim/blob/main/rubin_sim/maf/metrics/simple_metrics.py
#
# The coaddition of dataslice from per vist m5 is:
# ```
#   @staticmethod
#     def coadd(single_visit_m5s):
#         return 1.25 * np.log10(np.sum(10.0 ** (0.8 * single_visit_m5s)))
# ```

# %% [markdown]
# ### 1.1 ExgalM5 signature

# %%
# %pinfo ExgalM5

# %% [markdown]
# ### 1.2 ExgalM5 source

# %%
# %psource ExgalM5

# %% [markdown]
# ## 2 MAF metric GalaxyCountsMetricExtended

# %% [markdown]
# ### 2.1 GalaxyCountsMetricExtended signature

# %%
# %pinfo GalaxyCountsMetricExtended

# %% [markdown]
# ### 2.2 GalaxyCountsMetricExtended source

# %%
# %psource GalaxyCountsMetricExtended

# %% [markdown]
# ## 3 MAF metric DepthLimitedNumGalMetric

# %% [markdown]
# ### 3.1  DepthLimitedNumGalMetric signature

# %%
# %pinfo DepthLimitedNumGalMetric

# %% [markdown]
# ### 3.2  DepthLimitedNumGalMetric source

# %%
# %psource DepthLimitedNumGalMetric
